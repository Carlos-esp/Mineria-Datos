# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# El primer paso es importar las librerías

# %%
df=pd.read_csv("D:/Documentoss/Carlos/trabajos de la compu gris/Tareas de facultad/Semestre 7/mineria datos/unclean_data1.csv")
df
# Out:
#                                           movie_title  num_critic_for_reviews  \
# 0                                            Avatar?ÿ                   723.0
# 1          Pirates of the Caribbean: At World's End?ÿ                   302.0
# 2                                           Spectre?ÿ                   602.0
# 3                             The Dark Knight Rises?ÿ                   813.0
# 4   John Carter?ÿ,462,132,"""475""",530,640,730586...                     NaN
# 5                                      Spider-Man 3?ÿ                   392.0
# 6                                           Tangled?ÿ                   324.0
# 7                           Avengers: Age of Ultron?ÿ                   635.0
# 8                           Avengers: Age of Ultron?ÿ                   635.0
# 9            Harry Potter and the Half-Blood Prince?ÿ                   375.0
# 10               Batman v Superman: Dawn of Justice?ÿ                   673.0
# ...

# %% [markdown]
# En esta parte importamos la base de datos y vemos la tabla con los datos

# %%
df.shape
# Out:
# (14, 16)

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews       float64
# duration                     float64
# DIRECTOR_facebook_likes      float64
# actor_3_facebook_likes       float64
# ACTOR_1_facebook_likes       float64
# gross                        float64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews         float64
# budget                       float64
# title_year                   float64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
df.movie_title.dtypes
# Out:
# dtype('O')

# %%
df.duration.dtypes
# Out:
# dtype('float64')

# %%
df.isnull()
#data_frame.drop("",axis=1) sirve para eliminar una columna
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                    True      True                     True
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
df.isnull().any()
# Out:
# movie_title                  False
# num_critic_for_reviews        True
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes        True
# ACTOR_1_facebook_likes        True
# gross                         True
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews          True
# budget                        True
# title_year                    True
# ACTOR_2_facebook_likes        True
# imdb_score                    True
# title_year.1                  True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       1
# duration                     4
# DIRECTOR_facebook_likes      3
# actor_3_facebook_likes       1
# ACTOR_1_facebook_likes       1
# gross                        1
# num_voted_users              2
# Cast_Total_facebook_likes    3
# facenumber_in_poster         6
# num_user_for_reviews         1
# budget                       1
# title_year                   1
# ACTOR_2_facebook_likes       2
# imdb_score                   1
# title_year.1                 7
# dtype: int64

# %% [markdown]
# En estos bloques vemos la descripción general de la base de datos:
# - El tamaño de la base de datos, las columnas y filas
# - Los tipos de datos que hay
# - Las columnas que tienen valores nulos
# - La cantidad de valores nulos por columna

# %%
df
#df.movie_title.unique
#df=df.replace('\*',¨,regex=True).astype(float)
# Out:
#                                           movie_title  num_critic_for_reviews  \
# 0                                            Avatar?ÿ                   723.0
# 1          Pirates of the Caribbean: At World's End?ÿ                   302.0
# 2                                           Spectre?ÿ                   602.0
# 3                             The Dark Knight Rises?ÿ                   813.0
# 4   John Carter?ÿ,462,132,"""475""",530,640,730586...                     NaN
# 5                                      Spider-Man 3?ÿ                   392.0
# 6                                           Tangled?ÿ                   324.0
# 7                           Avengers: Age of Ultron?ÿ                   635.0
# 8                           Avengers: Age of Ultron?ÿ                   635.0
# 9            Harry Potter and the Half-Blood Prince?ÿ                   375.0
# 10               Batman v Superman: Dawn of Justice?ÿ                   673.0
# ...

# %%
#df1=df.rename(columns = {'imdb_score':'imdb', 'movie_title':'Película'})
#df1
df2=df.rename(columns = {'budget':'Costo', 'movie_title':'Película', 'imdb_score':'Calificacion'})
df2
# Out:
#                                              Película  num_critic_for_reviews  \
# 0                                            Avatar?ÿ                   723.0
# 1          Pirates of the Caribbean: At World's End?ÿ                   302.0
# 2                                           Spectre?ÿ                   602.0
# 3                             The Dark Knight Rises?ÿ                   813.0
# 4   John Carter?ÿ,462,132,"""475""",530,640,730586...                     NaN
# 5                                      Spider-Man 3?ÿ                   392.0
# 6                                           Tangled?ÿ                   324.0
# 7                           Avengers: Age of Ultron?ÿ                   635.0
# 8                           Avengers: Age of Ultron?ÿ                   635.0
# 9            Harry Potter and the Half-Blood Prince?ÿ                   375.0
# 10               Batman v Superman: Dawn of Justice?ÿ                   673.0
# ...

# %% [markdown]
# En este bloque cambiamos el nombre de las columnas que vamos a utilizar

# %%
dfn=df2.drop({'duration','num_critic_for_reviews', 'DIRECTOR_facebook_likes','actor_3_facebook_likes','ACTOR_1_facebook_likes','gross','num_voted_users','facenumber_in_poster','Cast_Total_facebook_likes','num_user_for_reviews','title_year','ACTOR_2_facebook_likes','title_year.1'},axis=1)
dfn
# Out:
#                                              Película        Costo  \
# 0                                            Avatar?ÿ  237000000.0
# 1          Pirates of the Caribbean: At World's End?ÿ  300000000.0
# 2                                           Spectre?ÿ  245000000.0
# 3                             The Dark Knight Rises?ÿ  250000000.0
# 4   John Carter?ÿ,462,132,"""475""",530,640,730586...          NaN
# 5                                      Spider-Man 3?ÿ  258000000.0
# 6                                           Tangled?ÿ  260000000.0
# 7                           Avengers: Age of Ultron?ÿ  250000000.0
# 8                           Avengers: Age of Ultron?ÿ  250000000.0
# 9            Harry Potter and the Half-Blood Prince?ÿ  250000000.0
# 10               Batman v Superman: Dawn of Justice?ÿ  250000000.0
# 11                                 Superman Returns?ÿ  209000000.0
# 12                                Quantum of Solace?ÿ  200000000.0
# ...
