# %%
umbral=.5
c=int(input(print("¿Hay juego? 1:Sí 2:No")))
print(c)
x=int(input(print("¿Cuál es el clima del día? 1:Soleado 2:Nublado 3:Lluvioso")))
print(x)

if c==1:
    prc= 9/14
    if x==1:
        prx=5/14
        prxc=3/9 
        prcx=(prxc*prc)/prx
        print(prcx)        
    elif x==2:
        prx=4/14
        prxc=4/9
        prcx=(prxc*prc)/prx
        print(prcx)        
        
    elif x==3:
        prx=5/14
        prxc=2/9     
        prcx=(prxc*prc)/prx
        print(prcx)        
        
    else:
        print("Valor inválido")
    
elif c==2:
    prc=5/14
    if x==1:
        prx=5/14
        prxc=2/5         
        prcx=(prxc*prc)/prx
        print(prcx)        
    elif x==2:
        prx=4/14
        prxc=0
        prcx=(prxc*prc)/prx
        print(prcx)        
    elif x==3:
        prx=5/14
        prxc=3/5
        prcx=(prxc*prc)/prx
        print(prcx)        
    else:
        print("Valor inválido")    
else:
    print("Valor no aceptado")
    
if prcx>umbral:
    print("La probabilidad es buena")
else:
    print("La probabilidad no es tan buena")
# Out:
# ¿Hay juego? 1:Sí 2:No
# None1
# 1
# ¿Cuál es el clima del día? 1:Soleado 2:Nublado 3:Lluvioso
# None3
# 3
# 0.39999999999999997
# La probabilidad no es tan buena

# %%
def bayes(juego, clima):
        
    if juego==1:
        prc= 9/14
        if clima==1:
            prx=5/14
            prxc=3/9 
            prcx=(prxc*prc)/prx
            return prcx        
        elif clima==2:
            prx=4/14
            prxc=4/9
            prcx=(prxc*prc)/prx
            return prcx        

        elif clima==3:
            prx=5/14
            prxc=2/9     
            prcx=(prxc*prc)/prx
            return prcx        

        else:
            print("Valor inválido")

    elif juego==2:
        prc=5/14
        if clima==1:
            prx=5/14
            prxc=2/5         
            prcx=(prxc*prc)/prx
            return prcx        
        elif clima==2:
            prx=4/14
            prxc=0
            prcx=(prxc*prc)/prx
            return prcx        
        elif clima==3:
            prx=5/14
            prxc=3/5
            prcx=(prxc*prc)/prx
            return prcx        
        else:
            print("Valor inválido")    
    else:
        print("Valor no aceptado")   
umbral=.5

juego=int(input(print("¿Hay juego? 1:Sí 2:No")))
clima=int(input(print("¿Cuál es el clima? 1:Soleado 2:Nublado 3:Lluvioso")))
print("La probabilidad es",bayes(juego,clima) )
if bayes(juego,clima)>=umbral:
    print('El caso expuesto es verdadero')
else:
    print("El caso expuesto es falso")
# Out:
# ¿Hay juego? 1:Sí 2:No
# None1
# ¿Cuál es el clima? 1:Soleado 2:Nublado 3:Lluvioso
# None1
# La probabilidad es 0.6
# El caso expuesto es verdadero
